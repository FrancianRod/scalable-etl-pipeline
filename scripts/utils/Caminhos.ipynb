# %%
pasta_hierarquia = "C:/Users/VeryPC/OneDrive - verytecnologia.com.br/4.PIAUÍ - 1.SEDUC/2. Execução/2.5 Projetos/Escritório de Projetos/4. Painéis/Painel iSEDUC/Indicadores_Hierarquia/"
pasta_hierarquia_historico = "C:/Users/VeryPC/OneDrive - verytecnologia.com.br/4.PIAUÍ - 1.SEDUC/2. Execução/2.5 Projetos/Escritório de Projetos/4. Painéis/Painel iSEDUC/Indicadores_Hierarquia"

# Caminhos csv Escola
caminho_escola = "Tab_especificações_indicadores/tabela_pivotada_matriculas_Escola.csv"
caminho_resultado_matriculas_Escola = "Indicadores_Escola/resultado_matriculas_Escola.csv"

# Caminhos csv Estado
caminho_estado = "Indicadores_Estado/tabela_pivotada_matriculas_Estado.csv"
caminho_resultado_matriculas_Estado = "Indicadores_Estado/resultado_matriculas_Estado.csv"

# Caminhos csv Gerencia Regional
caminho_ger_regional = "Indicadores_Gerencia_Regional/tabela_pivotada_matriculas_gerencia.csv"
caminho_resultado_matriculas_gerencia = "Indicadores_Gerencia_Regional/resultado_matriculas_gerencia.csv"

# Caminhos csv Municipio
caminho_municipio = "Indicadores_Municipio/tabela_pivotada_matriculas_Municipio.csv"
caminho_resultado_matriculas_municipio = "Indicadores_Municipio/resultado_matriculas_municipio.csv"

# Caminhos csv Territorio Desenvolvimento
caminho_territorio_des = "Indicadores_Territorio_Desenvolvimento/tabela_pivotada_matriculas_Territorio.csv"
caminho_resultado_matriculas_Territorio = "Indicadores_Territorio_Desenvolvimento/resultado_matriculas_Territorio.csv"

# Caminhos csv Especificacao Indicadores
caminho_especificacao_ind_projetos_df_csv = "Tab_especificações_indicadores/especificacao_ind_projetos_df.csv"
caminho_especificacao_ind_O_E_csv = "Tab_especificações_indicadores/especificacao_ind_O_E.csv"
caminho_especificacao_superintendencia_df_csv = "Tab_especificações_indicadores/especificacao_superintendencia_df.csv"
caminho_base_comparativa_csv = "Tab_especificações_indicadores/base_comparativa.csv"
caminho_tabela_notas_geral_csv = "Query_indicadores/tabela_notas_geral.csv"
caminho_tabela_clientes_csv = "Query_indicadores/tabela_clientes.csv"

# Caminhos pickle
caminho_tabela_clientes_pkl = "Query_indicadores/tabela_clientes.pkl"
caminho_tabela_ind_estrategico_pkl = "Query_indicadores/tabela_ind_estrategico.pkl"
caminho_tabela_alunos_pkl = "Query_indicadores/tabela_alunos.pkl"
caminho_tabela_indicadores_projetos_pkl = "Query_indicadores/tabela_indicadores_projetos.pkl"
caminho_especificacao_ind_projetos_df_pkl = "Query_indicadores/especificacao_ind_projetos_df.pkl"
caminho_especificacao_ind_O_E_pkl = "Query_indicadores/especificacao_ind_O_E.pkl"
caminho_tabela_base_gerada_pkl = "Query_indicadores/base_gerada.pkl"
caminho_indicador_censo_pkl = "Query_indicadores/indicador_censo.pkl"
caminho_indicador_censo_matriculas_pkl = "Query_indicadores/indicador_censo_matriculas.pkl"
caminho_tabela_professor_pkl = "Query_indicadores/tabela_professor.pkl"
caminho_tabela_notas_pkl = "Query_indicadores/tabela_notas.pkl"
caminho_tabela_notas_geral_pkl = "Query_indicadores/tabela_notas_geral.pkl"
caminho_tabela_frequencia_pkl = "Query_indicadores/tabela_frequencia.pkl"

# Caminhos parquet
caminho_tabela_indicadores_projetos_parquet = "Query_indicadores/tabela_indicadores_projetos.parquet"
caminho_tabela_alunos_parquet = "Query_indicadores/tabela_alunos.parquet"
caminho_tabela_ind_estrategico_parquet = "Query_indicadores/tabela_ind_estrategico.parquet"
caminho_tabela_clientes_parquet = "Query_indicadores/tabela_clientes.parquet"
caminho_tabela_base_gerada_parquet = "Query_indicadores/base_gerada.parquet"
caminho_tabela_professor_parquet = "Query_indicadores/tabela_professor.parquet"
caminho_tabela_notas_parquet = "Query_indicadores/tabela_notas.parquet"
caminho_tabela_notas_geral_parquet = "Query_indicadores/tabela_notas_geral.parquet"
caminho_tabela_frequencia_ativo_parquet = "Query_indicadores/tabela_frequencia.parquet"
caminho_tabela_frequencia_ITA_parquet = "Query_indicadores/tabela_frequencia_ITA.parquet"
caminho_especificacao_ind_O_E_parquet = "Query_indicadores/especificacao_ind_O_E.parquet"
caminho_base_comparativa_parquet = "Tab_especificações_indicadores/base_comparativa.parquet"
caminho_tabela_Tempo_Integral_parquet = "Query_indicadores/tabela_Tempo_Integral.parquet"
caminho_tabela_lotacao_Turma_parquet = "Query_indicadores/tabela_lotacao_Turma.parquet"
caminho_indicador_censo_parquet = "Query_indicadores/indicador_censo.parquet"
caminho_indicador_censo_matriculas_parquet = "Query_indicadores/indicador_censo_matriculas.parquet"
caminho_tabela_banco_dados_parquet = "Query_indicadores/tabela_banco_dados.parquet"

#Caminhos parquet
caminho_tabela_indicadores_projetos_feather = "Query_indicadores/tabela_indicadores_projetos.feather"
caminho_tabela_alunos_feather = "Query_indicadores/tabela_alunos.feather"
caminho_tabela_ind_estrategico_feather = "Query_indicadores/tabela_ind_estrategico.feather"
caminho_tabela_clientes_feather = "Query_indicadores/tabela_clientes.feather"
caminho_tabela_base_gerada_feather = "Query_indicadores/base_gerada.feather"
caminho_tabela_professor_feather = "Query_indicadores/tabela_professor.feather"
caminho_tabela_notas_feather = "Query_indicadores/tabela_notas.feather"
caminho_tabela_notas_geral_feather = "Query_indicadores/tabela_notas_geral.feather"
caminho_tabela_frequencia_feather = "Query_indicadores/tabela_frequencia.feather"
caminho_teste = "Query_indicadores/teste.csv"
caminho_teste1 = "Query_indicadores/teste1.csv"
caminho_teste2 = "Query_indicadores/teste2.csv"

# %%
# Conexão e Dataframe 10.10.1.87
dados_conexao_seduc = ("Driver={SQL Server};"
           "Server=10.10.1.87;"
           "Database=academico;"
           "UID=verytecnologia;"
           "PWD=7&`Hf^bj4Fr4")

# Conexão e Dataframe 10.10.1.58
dados_conexao_brisk = (("Driver={SQL Server};"
           "Server=briskdb.seduc.pi.gov.br,1433;"
           "Database=briskdb;"
           "UID=usr_briskdb_verytec_bi;"
           "PWD=ROcqvkm0Brisk@"))

# %%
import cx_Oracle

try:
    dsn_tns_oracle = cx_Oracle.makedsn('sc01-c1-scan.ati.pi.gov.br', '1521', service_name='SEDUCP')
    conexao_oracle = cx_Oracle.connect(user='data_estados', password='data_estados', dsn=dsn_tns_oracle)
    print("Conexão bem-sucedida!")
    conexao_oracle.close()
except cx_Oracle.DatabaseError as e:
    print("Erro ao conectar:", e)
# Out:
# Conexão bem-sucedida!
